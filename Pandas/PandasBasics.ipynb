# %%
import numpy as np
import pandas as pd

# %%
labels = ["a", "b", "c"]

# %%
mylist = [10, 20, 30]

# %%
array = np.array(mylist)

# %%
array
# Out:
# array([10, 20, 30])

# %%
d = {"a" : 10, "b" : 20, "c" : 30}

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data = mylist )
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(array)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = mylist, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data = [10, "a", 4.5, "b"])
# Out:
# 0     10
# 1      a
# 2    4.5
# 3      b
# dtype: object

# %%
series1 = pd.Series([1,2,3,4], index = ['India', 'USA', 'Japan', 'Korea'])

# %%
series1
# Out:
# India    1
# USA      2
# Japan    3
# Korea    4
# dtype: int64

# %%
series1["Korea"]
# Out:
# 4

# %%
series2 = pd.Series([5,6,7,8], index=['Brazil', 'Argentina', 'India', 'Japan'])

# %%
series2
# Out:
# Brazil       5
# Argentina    6
# India        7
# Japan        8
# dtype: int64

# %%
series1 + series2
# Out:
# Argentina     NaN
# Brazil        NaN
# India         8.0
# Japan        11.0
# Korea         NaN
# USA           NaN
# dtype: float64

# %%
from numpy.random import randn

# %%
np.random.seed(101)
rand_mat = randn(5, 4)

# %%
rand_mat
# Out:
# array([[ 2.70684984,  0.62813271,  0.90796945,  0.50382575],
#        [ 0.65111795, -0.31931804, -0.84807698,  0.60596535],
#        [-2.01816824,  0.74012206,  0.52881349, -0.58900053],
#        [ 0.18869531, -0.75887206, -0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732,  2.60596728,  0.68350889]])

# %%
df = pd.DataFrame(data = rand_mat)

# %%
df
# Out:
#           0         1         2         3
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509

# %%
df1 = pd.DataFrame(data = rand_mat, index = 'A B C D E'.split())

# %%
df1
# Out:
#           0         1         2         3
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df2 = pd.DataFrame(data = rand_mat, index ='A B C D E'.split(), columns = 'W X Y Z'.split())

# %%
df2
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df2['X']
# Out:
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: X, dtype: float64

# %%
type(df2['X'])
# Out:
# pandas.core.series.Series

# %%
list = ['W', 'Y']
df2[list]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077
# C -2.018168  0.528813
# D  0.188695 -0.933237
# E  0.190794  2.605967

# %%
df2[['X', 'Y']]
# Out:
#           X         Y
# A  0.628133  0.907969
# B -0.319318 -0.848077
# C  0.740122  0.528813
# D -0.758872 -0.933237
# E  1.978757  2.605967

# %%
df2['NEW'] = df2['X'] + df2['Y']

# %%
df2
# Out:
#           W         X         Y         Z       NEW
# A  2.706850  0.628133  0.907969  0.503826  1.536102
# B  0.651118 -0.319318 -0.848077  0.605965 -1.167395
# C -2.018168  0.740122  0.528813 -0.589001  1.268936
# D  0.188695 -0.758872 -0.933237  0.955057 -1.692109
# E  0.190794  1.978757  2.605967  0.683509  4.584725

# %%
df2.drop("NEW", axis = 1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df2
# Out:
#           W         X         Y         Z       NEW
# A  2.706850  0.628133  0.907969  0.503826  1.536102
# B  0.651118 -0.319318 -0.848077  0.605965 -1.167395
# C -2.018168  0.740122  0.528813 -0.589001  1.268936
# D  0.188695 -0.758872 -0.933237  0.955057 -1.692109
# E  0.190794  1.978757  2.605967  0.683509  4.584725

# %%
df2.drop("NEW", axis = 1, inplace = True)

# %%
df2
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df2.drop("E", axis = 0, inplace = True)

# %%
df2
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df2.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df2.iloc[0]
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df2.loc[['A','C','D']]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df2.iloc[[0,2,3]]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df2
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df2.loc[['B', 'C']][['Y', 'Z']]
# Out:
#           Y         Z
# B -0.848077  0.605965
# C  0.528813 -0.589001

# %%
df2
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df2_bool = df2 > 0
df2_bool
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True

# %%
df2[df2_bool]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057

# %%
df2[df2 > 0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057

# %%
df2['W'] > 0
# Out:
# A     True
# B     True
# C    False
# D     True
# Name: W, dtype: bool

# %%
df2[df2['W'] > 0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
condition1 = df2['W'] > 0
condition2 = df2['Y']  > 0
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df2[condition1 & condition2]
# Out:
#          W         X         Y         Z
# A  2.70685  0.628133  0.907969  0.503826

# %%
df2[condition1 | condition2]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df2.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057

# %%
df2
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
new_index = 'INDIA JAPAN KOREA USA'.split()

# %%
new_index
# Out:
# ['INDIA', 'JAPAN', 'KOREA', 'USA']

# %%
df2['COUNTRY'] = new_index

# %%
df2
# Out:
#           W         X         Y         Z COUNTRY
# A  2.706850  0.628133  0.907969  0.503826   INDIA
# B  0.651118 -0.319318 -0.848077  0.605965   JAPAN
# C -2.018168  0.740122  0.528813 -0.589001   KOREA
# D  0.188695 -0.758872 -0.933237  0.955057     USA

# %%
df2.set_index("COUNTRY")
# Out:
#                 W         X         Y         Z
# COUNTRY
# INDIA    2.706850  0.628133  0.907969  0.503826
# JAPAN    0.651118 -0.319318 -0.848077  0.605965
# KOREA   -2.018168  0.740122  0.528813 -0.589001
# USA      0.188695 -0.758872 -0.933237  0.955057

# %%
df2
# Out:
#           W         X         Y         Z COUNTRY
# A  2.706850  0.628133  0.907969  0.503826   INDIA
# B  0.651118 -0.319318 -0.848077  0.605965   JAPAN
# C -2.018168  0.740122  0.528813 -0.589001   KOREA
# D  0.188695 -0.758872 -0.933237  0.955057     USA

# %%
df2.set_index("COUNTRY", inplace = True)

# %%
df2
# Out:
#                 W         X         Y         Z
# COUNTRY
# INDIA    2.706850  0.628133  0.907969  0.503826
# JAPAN    0.651118 -0.319318 -0.848077  0.605965
# KOREA   -2.018168  0.740122  0.528813 -0.589001
# USA      0.188695 -0.758872 -0.933237  0.955057

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, INDIA to USA
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       4 non-null      float64
#  1   X       4 non-null      float64
#  2   Y       4 non-null      float64
#  3   Z       4 non-null      float64
# dtypes: float64(4)
# memory usage: 332.0+ bytes

# %%
df2.dtypes
# Out:
# W    float64
# X    float64
# Y    float64
# Z    float64
# dtype: object

# %%
df2.describe()
# Out:
#               W         X         Y         Z
# count  4.000000  4.000000  4.000000  4.000000
# mean   0.382124  0.072516 -0.086133  0.368962
# std    1.938687  0.730102  0.942434  0.667223
# min   -2.018168 -0.758872 -0.933237 -0.589001
# 25%   -0.363021 -0.429207 -0.869367  0.230619
# 50%    0.419907  0.154407 -0.159632  0.554896
# 75%    1.165051  0.656130  0.623602  0.693238
# max    2.706850  0.740122  0.907969  0.955057

# %%
df2
# Out:
#                 W         X         Y         Z
# COUNTRY
# INDIA    2.706850  0.628133  0.907969  0.503826
# JAPAN    0.651118 -0.319318 -0.848077  0.605965
# KOREA   -2.018168  0.740122  0.528813 -0.589001
# USA      0.188695 -0.758872 -0.933237  0.955057

# %%
df2['W'] > 0
# Out:
# COUNTRY
# INDIA     True
# JAPAN     True
# KOREA    False
# USA       True
# Name: W, dtype: bool

# %%
ser_w = df2['W'] > 0

# %%
ser_w.value_counts()
# Out:
# True     3
# False    1
# Name: W, dtype: int64

# %%
sum(ser_w)
# Out:
# 3

# %%
len(ser_w)
# Out:
# 4

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df3 = pd.DataFrame(data)

# %%
df3
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df3.groupby('Company')

# %%
df3.groupby("Company").sum()
# Out:
# <ipython-input-110-6979bb208b90>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3.groupby("Company").sum()
#          Sales
# Company
# FB         593
# GOOG       320
# MSFT       464

# %%
df3.groupby("Company").mean()
# Out:
# <ipython-input-111-b2f615662267>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3.groupby("Company").mean()
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df3.groupby("Company").describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df3.groupby("Company").describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
df4 = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})

# %%
df4
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df4['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df4['col2'].nunique()
# Out:
# 3

# %%
df4['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df4
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df5 = df4[(df4['col1'] > 2) & (df4['col2'] == 444)]

# %%
df5
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %%
def times_two(number):
  return number*2

# %%
times_two(8)
# Out:
# 16

# %%
df4
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df4['col2'].apply(times_two)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df4
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df4['new'] = df4['col1'].apply(times_two)

# %%
df4
# Out:
#    col1  col2 col3  new
# 0     1   444  abc    2
# 1     2   555  def    4
# 2     3   666  ghi    6
# 3     4   444  xyz    8

# %%
del df4['new']

# %%
df4
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df4.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      int64
#  1   col2    4 non-null      int64
#  2   col3    4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df4.describe()
# Out:
#            col1        col2
# count  4.000000    4.000000
# mean   2.500000  527.250000
# std    1.290994  106.274409
# min    1.000000  444.000000
# 25%    1.750000  444.000000
# 50%    2.500000  499.500000
# 75%    3.250000  582.750000
# max    4.000000  666.000000

# %%
df4
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df4.sort_values(by='col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %% [markdown]
# Data Input and Output

# %%
pd.read_csv('example.csv')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df5 = pd.read_csv('example.csv')

# %%
df5
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df5 = df[['a', 'b']]

# %%
df5
# Out:
#     a   b
# 0   0   1
# 1   4   5
# 2   8   9
# 3  12  13

# %%
df5.to_csv('new.csv', index = False)

# %%
df6 = pd.read_csv('new.csv')

# %%
df6
# Out:
#     a   b
# 0   0   1
# 1   4   5
# 2   8   9
# 3  12  13

# %%
pd.read_excel("Excel_Sample.xlsx", sheet_name ='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df6 = pd.read_excel("Excel_Sample.xlsx", sheet_name = "Sheet1")

# %%
df6.columns
# Out:
# Index(['Unnamed: 0', 'a', 'b', 'c', 'd'], dtype='object')

# %%
df6.drop("Unnamed: 0", axis = 1, inplace=True)

# %%
df6
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15
